# %%
print("Hello world")
#Declaring A variable 
a=10
b=20
print(a,b)
print(f"My first variable {a} and second variable is {b}")
#type of the data
print(type(a))
# Out:
# Hello world
# 10 20
# My first variable 10 and second variable is 20
# <class 'int'>
